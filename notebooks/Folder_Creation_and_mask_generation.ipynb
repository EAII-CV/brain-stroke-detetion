# %%
# import required modules
import os
import cv2

# %%
    # folder to be created
directory = "Mask"
directory1="Scan"
# Parent Directories 
parent_dir = 'C:/Users/AI/Desktop/Normal'
# New Path 
path = os.path.join(parent_dir, directory) 
path1 = os.path.join(parent_dir, directory1) 
# Create the directory 
# 'Mask' 
os.makedirs(path)
os.makedirs(path1)  
print("Directory '% s' created" % directory)
# Out:
# Directory 'Mask' created

# %% [markdown]
# # Creating the patient name folders

# %%
pth='C:/Users/AI/Desktop/Data/NORMAL'
patient_fldr=os.listdir(pth)
for i in patient_fldr:
    # print each patient folder name 
    directory2=i
    parent_dir = 'C:/Users/AI/Desktop/Normal'

# New Path 
    path = os.path.join(parent_dir, directory2)
    os.makedirs(path)

    print("Directory '% s' created" % directory) 
    #path1 = os.path.join(parent_dir, directory1)
# Out:
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created

# %% [markdown]
# # Creating Mask and Scan subfolders for each Patient

# %%
pth='C:/Users/AI/Desktop/Normal'
patient_fldr=os.listdir(pth)

#print(patient_fldr)
for i in patient_fldr:
    # print each patient folder name 
    print(i)
    pth='C:/Users/AI/Desktop/Normal/'+i+'/'
    # os.listdir read files in folder as array combination, so we can easly get each files by using for loop
    #slices=os.listdir(pth)
 
    # folder to be created
    directory = "Mask"
    directory1="Scan"
    # Parent Directories 
    parent_dir = 'C:/Users/AI/Desktop/Normal/'+i
    #print(parent_dir)
    # New Path 
    path = os.path.join(parent_dir, directory) 
    path1 = os.path.join(parent_dir, directory1) 
    # Create the directory 
    # 'Mask' 
    os.makedirs(path)
    os.makedirs(path1)  
    print("Directory '% s' created" % directory)
# Out:
# N10[N10]
# N11[N11]
# N12[N12]
# N13[N13]
# N14[N14]
# N15[N15]
# N16[N16]
# N17[N17]
# N18[N18]
# N19[N19]
# N1[N1]
# N20[N20]
# N21[N21]
# N22[N22]
# N23[N23]
# N24[N24]
# N25[N25]
# N26[N26]
# N27[N27]
# N2[N2]
# N3[N3]
# N4[N4]
# N5[N5]
# N6[N6]
# N7[N7]
# N8[N8]
# N9[N9]

# %% [markdown]
# # Copying the slices of each patients in to apropriate scan folder and black mask generation

# %%
import glob
import cv2
# Base folder for Normal patient
pth="C:/Users/AI/Desktop/Normal/"
# List of patients
patient=os.listdir(pth)

for i in patient:
    pth5=os.listdir('C:/Users/AI/Desktop/archive (16)/Data/NORMAL/'+i+'/')
    # Lists of slices or iterating over each slice of patient
    for j in pth5:
        imgs=cv2.imread('C:/Users/AI/Desktop/archive (16)/Data/NORMAL/'+i+'/'+j)
        filename = os.path.basename(j)
        imgs=imgs*0

        # print(filename)
        # print(imgs)
        
        cv2.imwrite('C:/Users/AI/Desktop/Normal/'+i+'/Mask/'+filename,imgs)


#print(c)

# %%
import cv2
import os
folders='C:/Users/AI/Desktop/Hemorrhage/'
#C:\Users\AI\Desktop\Hemorrhage - 1\049\Scan
for k in os.listdir(folders):
    sub_folders=os.listdir('C:/Users/AI/Desktop/Hemorrhage/'+k)
    c=0
    for s in sub_folders:
        if (s=='Mask'):
            print(len(os.listdir('C:/Users/AI/Desktop/Hemorrhage/'+k+'/'+s)))
        elif(s=='Scan'):
            f=os.listdir('C:/Users/AI/Desktop/Hemorrhage/'+k+'/'+s)
            for i in f:
                print(i)
                imgs=cv2.imread('C:/Users\AI/Desktop/Hemorrhage - 1/'+k+'/'+'Scan'+'/'+i)
                #imgs=imgs*0
                filename = os.path.basename(i)
                cv2.imwrite('C:/Users/AI/Desktop/Hemorrhage/'+k+'/'+'Scan'+'/'+filename,imgs)

                #imgs=imgs*0



        # print(filename)
        # print(imgs)
        
        #cv2.imwrite('C:/Users/AI/Desktop/Normal/'+i+'/Mask/'+filename,imgs)

        #M_S=os.listdir('C:/Users/AI/Desktop/Hemorrhage/'+k+'/'+s)
        #for ms in M_S:
            #print(ms)
# Out:
# 31
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 31.jpg
# 32.jpg
# 33.jpg
# 4.jpg
# 5.jpg
# 6.jpg
# 7.jpg
# 8.jpg
# 9.jpg
# 33
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 29.jpg
# 3.jpg
# 30.jpg
# 31.jpg
# 32.jpg
# 33.jpg
# 4.jpg
# 5.jpg
# 6.jpg
# 7.jpg
# 8.jpg
# 9.jpg
# 28
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# 26.jpg
# 27.jpg
# 28.jpg
# 3.jpg
# 4.jpg
# 5.jpg
# 6.jpg
# 7.jpg
# 8.jpg
# 9.jpg
# 34
# 1.jpg
# 10.jpg
# 11.jpg
# 12.jpg
# 13.jpg
# 14.jpg
# 15.jpg
# 16.jpg
# 17.jpg
# 18.jpg
# 19.jpg
# 2.jpg
# 20.jpg
# 21.jpg
# 22.jpg
# 23.jpg
# 24.jpg
# 25.jpg
# ...
