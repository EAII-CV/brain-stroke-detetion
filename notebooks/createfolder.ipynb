# %%
import os
pth=r'D:/EAII_BRAINSTROK/AI_Ethiopia/justrail/brainstrokeproject/justtrail/mixednopad'
patient_fldr=os.listdir(pth)

# %%
for i in patient_fldr:
    # print each patient folder name 
    directory2= ('skullremoved')
    parent_dir = os.path.join(r'D:/EAII_BRAINSTROK/AI_Ethiopia/justrail/brainstrokeproject/justtrail/mixednopad/',i)

# New Path 
    path = os.path.join(parent_dir, directory2)
    os.makedirs(path)

    print("Directory '% s' created" % directory2) 
    #path1 = os.path.join(parent_dir, directory1)
# Out:
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# Directory 'skullremoved' created
# ...

# %%
import os
pth=r'D:\Local_DataV2\all_in_one'
patient_fldr=os.listdir(pth)
print (patient_fldr)
# Out:
# ['0019983', '0021092', '0021822', '0041698', '0041699', '0072680', '0072681', '0072682', '0072688', '0072691', '0072723', '0072729', '0072752', '0072762', '0072765', '0072776', '0072864', '0072916', '0072921', '0072946', '0072950', '0072961', '0072975', '0073000', '0073060', '0073074', '0226201', '0226205', '0226259', '18223', '18223_14', '18697', '18697_14', '1870LANC', '18928_14', '18987', '18999', '19109_14d', '19113_14d', '19117_14d', '19268_14d', '19308_14d', '19354_14d', '19374_14d', '19444_14d', '19500_14d', '19584_14d', '19588_14', '19588_14d', '19644_14', '19644_14d', '19845_14', '19845_14d', '19848_14', '19848_14d', '675_14', '79', '80', '80(2)', '8683_12', '91', '91(2)', '92', 'ABDURAHMAN_KEDIR 10963', 'ABDURAHMAN_TEJO 10693', 'ABEBECH_BOCHO 11011', 'AKILILU_HIRPO 10925', 'ALEMITU_FITA 10697', 'AMARECH_MENGISTU 10995', 'AMIN_ABDULAHIM 10857', 'AMIN_ABDURAHIM 10749', 'AYALEW_AJAMA 10827', 'AYISHA_SHKUR 10862', 'BABY_SAMIRA 10831', 'BANETA_ELEMA 10664', 'BARARA_MULATU 10811'
# ...

# %%
for i in patient_fldr:
    # print each patient folder name 
    directory2= patient_fldr
    parent_dir = os.path.join('D:/EAII_BRAINSTROK/AI_Ethiopia/justrail/brainstrokeproject/justtrail/normalzdminmax/scan/'+ str(i))

# New Path 
    path = os.path.join(parent_dir, directory2)
    os.makedirs(path)

    print("Directory '% s' created" % directory2) 
    #path1 = os.path.join(parent_dir, directory1)
# Out:
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# Directory 'Mask' created
# ...
